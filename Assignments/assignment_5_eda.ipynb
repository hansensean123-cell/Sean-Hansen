# %% [markdown]
# <a href="https://colab.research.google.com/github/hansensean123-cell/Sean-Hansen/blob/main/Assignments/assignment_5_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Assignment 5: Exploratory Data Analysis (EDA) with Stakeholder Framing
#
# In this assignment, you will:
# - Load and explore a hotel bookings dataset
# - Identify stakeholder needs and frame your analysis around business goals
# - Practice data summarization and visualization
# - Draw insights that could lead to actionable business recommendations
#
# ## Why This Matters
#
# These skills are essential for business majors and minors working in areas like marketing, operations, finance, or consulting. Understanding how to explore and communicate data-driven insights helps you make better decisions and contribute to real-world business outcomes.
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Assignments/assignment_5_eda.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Dataset Description: Hotel Bookings
#
# This dataset contains booking information for two types of hotels: a **city hotel** and a **resort hotel**. Each record corresponds to a single booking and includes various details about the reservation, customer demographics, booking source, and whether the booking was canceled.
#
# **Source**: [GitHub - TidyTuesday: Hotel Bookings](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-02-11/readme.md)
#
# ### Key Use Cases
# - Understand customer booking behavior
# - Explore factors related to cancellations
# - Segment guests based on booking characteristics
# - Compare city vs. resort hotel performance
#
# ### Data Dictionary
#
# | Variable | Type | Description |
# |----------|------|-------------|
# | `hotel` | character | Hotel type: City or Resort |
# | `is_canceled` | integer | 1 = Canceled, 0 = Not Canceled |
# | `lead_time` | integer | Days between booking and arrival |
# | `arrival_date_year` | integer | Year of arrival |
# | `arrival_date_month` | character | Month of arrival |
# | `stays_in_weekend_nights` | integer | Nights stayed on weekends |
# | `stays_in_week_nights` | integer | Nights stayed on weekdays |
# | `adults` | integer | Number of adults |
# | `children` | integer | Number of children |
# | `babies` | integer | Number of babies |
# | `meal` | character | Type of meal booked |
# | `country` | character | Country code of origin |
# | `market_segment` | character | Booking source (e.g., Direct, Online TA) |
# | `distribution_channel` | character | Booking channel used |
# | `is_repeated_guest` | integer | 1 = Repeated guest, 0 = New guest |
# | `previous_cancellations` | integer | Past booking cancellations |
# | `previous_bookings_not_canceled` | integer | Past bookings not canceled |
# | `reserved_room_type` | character | Initially reserved room type |
# | `assigned_room_type` | character | Room type assigned at check-in |
# | `booking_changes` | integer | Number of booking modifications |
# | `deposit_type` | character | Deposit type (No Deposit, Non-Refund, etc.) |
# | `agent` | character | Agent ID who made the booking |
# | `company` | character | Company ID (if booking through company) |
# | `days_in_waiting_list` | integer | Days on the waiting list |
# | `customer_type` | character | Booking type: Contract, Transient, etc. |
# | `adr` | float | Average Daily Rate (price per night) |
# | `required_car_parking_spaces` | integer | Requested parking spots |
# | `total_of_special_requests` | integer | Number of special requests made |
# | `reservation_status` | character | Final status (Canceled, No-Show, Check-Out) |
# | `reservation_status_date` | date | Date of the last status update |
#
# This dataset is ideal for classification, segmentation, and trend analysis exercises.

# %% [markdown]
# ## 1. Setup and Data Loading
#
# Instructions:
# - Import `pandas`, `seaborn`, and `matplotlib.pyplot`.
# - Load the dataset from this URL:
#   https://github.com/Stan-Pugsley/is_4487_base/blob/d764a81fe649c397a1f5b35f1e1ceda48b5178d1/DataSets/hotels.csv?raw=true
# - Display the first few rows to confirm it loaded correctly.

# %%
# Your code to import libraries and load data goes here
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ## 2. Stakeholder and Business Context
#
# Business framing:
#
# Every analysis should serve a decision-maker. Before you explore the data, identify who cares about hotel booking behavior and what they might want to know. Your analysis should be framed around those needs.
#
# ### In your markdown:
# 1. Who are the key stakeholders for this dataset?
# 2. What goals might each stakeholder have?
# 3. What is a clear, specific business problem statement that this data can help answer?

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1. Some key stakeholders for this dataset are the marketing department, hotel management, sales department, and financial analysts.
#
# 2. Marketing departments goals are to understand demographics of customers so they can target their campaigns effectively. The hotel management wants to maximize their revenue by keeping rooms full and booked while reducing costs. The sales department want to see where the biggest profits are in the company so they can improve sale strategies. Finally, financial analysts want to be able to forecast profits and identify ways to save money.
#
# 3. How can we leverage booking data to identify key drivers of cancellations and develop targeted strategies to reduce cancellation rates and optimize revenue across both city and resort hotels?

# %% [markdown]
# ## 3. Explore Data Structure and Quality
#
# Business framing:
#
# Before diving into analysis, analysts need to understand the shape and health of the data. Bad data leads to bad decisions.
#
# - Perform the following 3 checks to see the data quality:
#   - Summary the data (e.g., `.info()`, `.describe()`)
#   - Find the number of Null values
#   - Find the number of duplicate row checks
# - Flag any issues you notice (e.g., missing values, formatting problems)

# %%
# Add code here 🔧
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
# ...

# %% [markdown]
# ### In your markdown:
# 1. What structural issues or problems did you find?
# 2. What actions would you recommend to clean or prepare this dataset for use?
#
# ### ✍️ Your Response: 🔧
# 1. I found that there were missing values in the children (4), country (488), agent (16340), and company (112593). Also row 31994 was a duplicate row.
#
# 2. To clean up the dataset, I would investigate the cause of missingness for the children and company columns. For agent and company columns, I would drop them because they aren't that important to the overall analysis. I would also go back and delete the duplicate rows. Finally, I would change the reservation_status_date to a datetime object for a better analysis.

# %% [markdown]
# ## 4. Univariate Analysis
#
# Business framing:
#
# Hotels care about trends like average stay length, customer mix, and pricing. A good EDA starts with understanding single variables and their distribution.
#
# - Select at least 3 individual variables to explore
# - Use plots and summary methods (e.g. info(), describe(), etc)  to describe the distribution (hint: we are only looking at the values of one variable, so think of plots you've used in the past that DON'T compare 2 variables.)
# - Focus on what matters from a business standpoint (e.g., pricing, cancellations, guest types)

# %%
# Your code for univariate analysis (e.g., plots, value counts) 🔧
# Out:
# Analysis of Average Daily Rate (adr):
# count    119390.000000
# mean        101.831122
# std          50.535790
# min          -6.380000
# 25%          69.290000
# 50%          94.575000
# 75%         126.000000
# max        5400.000000
# Name: adr, dtype: float64
# Analysis of Hotel Type:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64
# Analysis of Is Canceled:
# is_canceled
# 0    75166
# 1    44224
# Name: count, dtype: int64

# %% [markdown]
# ### In your markdown:
# 1. Variable 1 – What did you explore and what did you find?
# 2. Variable 2 – What did you explore and what did you find?
# 3. Variable 3 – What did you explore and what did you find?
#
# ### ✍️ Your Response: 🔧
# - **Variable 1 – Summary and insights:** Average Daily Rate: I found that the mean ADR was just about $102. The maximum was $5400, and the minimum was -$6. The negative has got to be an error because it doesn't make sense.
# - **Variable 2 – Summary and insights:** What type of hotel: There was 79,330 bookings for city hotels and 40,060 bookings for resort hotels.
# - **Variable 3 – Summary and insights:** Canceled or not: There was 75,166 bookings that weren't canceled and 44,224 bookings that were canceled between the two types of hotels.

# %% [markdown]
# ## 5. Bivariate Analysis
#
# Business framing:
#
# Stakeholders often ask: “What drives cancellations?” or “Do longer stays mean higher revenue?” Bivariate analysis helps you uncover those kinds of relationships.
#
# - Choose 2 relevant variable pairs (e.g., `lead_time` vs. `is_canceled`, or `adr` vs. `customer_type`)
# - Use scatterplots, grouped bar plots, or boxplots to explore the relationships
# - Interpret what these relationships could mean for the hotel business

# %%
# Your code to analyze variable relationships (e.g., scatterplots, grouped bars) 🔧

# %% [markdown]
# ### In your markdown:
# 1. Relationship 1 – What did you analyze and what insights did you find?
# 2. Relationship 2 – What did you analyze and what insights did you find?
#
# ### ✍️ Your Response: 🔧
# - **Relationship 1:**  I analyzed the relationship between how far in advance a booking is made (lead_time) and whether the booking is canceled (is_canceled) using a box plot. The box plot shows that canceled bookings tend to have a higher median lead time compared to non-canceled bookings. This suggests that bookings made further in advance are more likely to be canceled.
# - **Relationship 2:** I analyzed the relationship between the type of hotel (hotel) and the Average Daily Rate (adr) using a box plot. The box plot indicates that City Hotels generally have a higher median ADR compared to Resort Hotels. Both hotel types have outliers with very high ADR values, but City Hotels appear to have a wider spread of ADR values and higher maximum values excluding the extreme outliers. This suggests that City Hotels might have a more varied pricing structure or attract different customer segments willing to pay higher rates.

# %% [markdown]
# ## 6. Problem Complexity and Analytics Framing
#
# Business framing:
#
# Let’s say you found a strong trend — maybe high lead times predict cancellations, or certain channels bring repeat guests. What kind of problem is this?
#
# - Choose one insight from your earlier analysis
# - Reflect on:
#   - What type of complexity this problem represents (e.g., variety, volume, variability)
#   - What kind of analytics would help solve or explain it (descriptive, diagnostic, predictive, prescriptive)
#
# ### In your markdown:
# 1. What was your selected insight?
# 2. What kind of complexity does it involve?
# 3. What type of analytics would help, and why?

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1.  Bookings made with a higher lead time are more likely to be canceled.
# 2. There are high levels of variability due to factors such as market segment, deposit type, time of year, and external events. Also the dataset is massive, so volume plays a role in making effective processing.
# 3. Predictive analytics would be the best option. This is because we are trying to find bookings that are going to be canceled before they get canceled. Machine learning models or logistic regression would be the best ways to go about building a model to predict the probability of this happening.

# %% [markdown]
# ## 7. Final Takeaways and Recommendations
#
# Business framing:
#
# Imagine you’re preparing for a stakeholder meeting. What would you highlight from your findings?
#
# - Identify your top 2–3 insights or patterns
# - Connect each to a stakeholder need or business goal
# - Make one recommendation based on the analysis
#
# ### In your markdown:
# 1. What patterns or trends stood out?
# 2. How do they connect to stakeholder goals?
# 3. What recommendation would you make based on this analysis?
# 4. How does this relate to your customized learning outcome you created in canvas?

# %% [markdown]
# ### ✍️ Your Response: 🔧
#
# 1. **Patterns or Trends:**
#     *   **High Cancellation Rate:** A significant portion of bookings (around 37%) are being canceled.
#     *   **Lead Time and Cancellations:** Bookings made with longer lead times show a higher propensity for cancellation.
#     *   **Hotel Type and ADR:** City Hotels generally have a higher Average Daily Rate compared to Resort Hotels.
#
# 2. **Connection to Stakeholder Goals:**
#     *   **Hotel Management & Financial Analysts:** The high cancellation rate directly impacts revenue and occupancy (Hotel Management's goal to maximize revenue/occupancy, Financial Analysts' goal to forecast profits). Understanding the link between lead time and cancellations can help in managing revenue and risk.
#     *   **Marketing & Sales Departments:** The difference in ADR between hotel types highlights potential differences in customer segments or pricing strategies that these departments can leverage for targeted campaigns and sales efforts. The cancellation insights are also crucial for understanding customer behavior and optimizing acquisition costs.
#
# 3. **Recommendation:**
#     Given the insight that longer lead times are associated with higher cancellation rates, I recommend implementing a **targeted outreach strategy** for bookings made far in advance. This could involve:
#     *   Sending personalized reminders or value-added offers closer to the arrival date.
#     *   Implementing stricter deposit policies or non-refundable rates for bookings with very long lead times, especially in City Hotels where ADR is higher.
#     *   Gathering feedback from canceled bookings with long lead times to understand the underlying reasons.
#
# 4. **Relation to Customized Learning Outcome:**
#     This analysis directly relates to a learning outcome focused on using data to inform business decisions and address specific business problems. By identifying patterns in booking data (like the relationship between lead time and cancellations) and connecting them to stakeholder goals (reducing cancellations, optimizing revenue), and then proposing a data-driven recommendation (targeted outreach), I have demonstrated the ability to apply exploratory data analysis techniques to derive actionable insights for a business context, which aligns with a learning outcome around leveraging data for strategic decision-making in areas like revenue management or marketing.

# %% [markdown]
# ### ✍️ Your Response: 🔧
#
# 1. Around 37% of bookings are being canceled. Bookings that are farther out have a higher chance of being canceled. The ADR is higher at city hotels compared to resort hotels.
#
# 2. The high cancellation rate directly impacts revenue and occupancy. Understanding the link between lead time and cancellations can help in managing revenue and risk for hotel management and financial analysts. For marketing and sales departments, the difference in ADR between hotel types highlights potential differences in customer segments or pricing strategies that these departments can leverage for targeted campaigns and sales efforts. The cancellation insights are also crucial for understanding customer behavior and optimizing acquisition costs.
#
# 3. Given the insight that longer lead times are associated with higher cancellation rates, I recommend implementing a targeted outreach strategy for bookings made far in advance. This could include sending personalized reminders or value-added offers closer to the arrival date, or implementing stricter deposit policies or non-refundable rates for bookings with very long lead times, especially in City Hotels where ADR is higher.
#
# 4. This analysis directly relates to a learning outcome focused on using data to inform business decisions and address specific business problems. By identifying patterns in booking data (like the relationship between lead time and cancellations) and connecting them to stakeholder goals (reducing cancellations, optimizing revenue), and then proposing a data-driven recommendation (targeted outreach).

# %% [markdown]
# ## Submission Instructions
#
# ✅ **Before submitting:**
# - Make sure all code cells are run and outputs are visible
# - All markdown questions are answered thoughtfully
# - Submit the assignment as an **HTML file** on Canvas

# %%
# !jupyter nbconvert --to html "assignment_05_LastnameFirstname.ipynb"
